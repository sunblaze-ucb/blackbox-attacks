# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
sa_thin = np.load('static_adv_thin.npy')
print sa_thin.shape, sa_thin.dtype
plt.imshow(sa_thin[0])
plt.show()
# Out:
# (50000, 32, 32, 3) uint8

# %%
sa_wide = np.load('static_adv_wide.npy')
print sa_wide.shape, sa_wide.dtype
plt.imshow(sa_wide[0])
plt.show()
# Out:
# (50000, 32, 32, 3) uint8

# %%
sa_tutorial = np.load('static_adv_tutorial.npy')
print sa_tutorial.shape, sa_tutorial.dtype
plt.imshow(sa_tutorial[0])
plt.show()
# Out:
# (50000, 32, 32, 3) uint8
